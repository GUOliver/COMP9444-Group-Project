# %% [markdown]
# <a href="https://colab.research.google.com/github/GUOliver/COMP9444-Group-Project/blob/Peter/setupGit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
! git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
! git clone https://github.com/GUOliver/COMP9444-Group-Project.git
# Out:
# Cloning into 'COMP9444-Group-Project'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (7/7), done.

# %%
! pwd
! ls
# Out:
# /content
# COMP9444-Group-Project	sample_data

# %%
# %cd COMP9444-Group-Project/
# Out:
# /content/COMP9444-Group-Project

# %%
! git remote -v
# Out:
# origin	https://github.com/GUOliver/COMP9444-Group-Project.git (fetch)
# origin	https://github.com/GUOliver/COMP9444-Group-Project.git (push)

# %%
! git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git checkout Peter
# Out:
# Branch 'Peter' set up to track remote branch 'Peter' from 'origin'.
# Switched to a new branch 'Peter'

# %%
# !wget "https://os.unil.cloud.switch.ch/fma/fma_small.zip"
# Out:
# --2022-10-28 08:03:31--  https://os.unil.cloud.switch.ch/fma/fma_small.zip
# Resolving os.unil.cloud.switch.ch (os.unil.cloud.switch.ch)... 86.119.28.16, 2001:620:5ca1:201::214
# Connecting to os.unil.cloud.switch.ch (os.unil.cloud.switch.ch)|86.119.28.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7679594875 (7.2G) [application/zip]
# Saving to: ‘fma_small.zip’
#
# fma_small.zip       100%[===================>]   7.15G  30.2MB/s    in 4m 6s
#
# 2022-10-28 08:07:37 (29.8 MB/s) - ‘fma_small.zip’ saved [7679594875/7679594875]

# %%
! git status
# Out:
# On branch Peter
# Your branch is up to date with 'origin/Peter'.
#
# nothing to commit, working tree clean

# %%
# !unzip fma_small.zip
# Out:
# Archive:  fma_small.zip
# replace fma_small/README.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#  bunzipping: fma_small/checksums
#  bunzipping: fma_small/000/000002.mp3
#  bunzipping: fma_small/000/000005.mp3
#  bunzipping: fma_small/000/000010.mp3
#  bunzipping: fma_small/000/000140.mp3
#  bunzipping: fma_small/000/000141.mp3
#  bunzipping: fma_small/000/000148.mp3
#  bunzipping: fma_small/000/000182.mp3
#  bunzipping: fma_small/000/000190.mp3
#  bunzipping: fma_small/000/000193.mp3
#  bunzipping: fma_small/000/000194.mp3
#  bunzipping: fma_small/000/000197.mp3
#  bunzipping: fma_small/000/000200.mp3
#  bunzipping: fma_small/000/000203.mp3
#  bunzipping: fma_small/000/000204.mp3
#  bunzipping: fma_small/000/000207.mp3
#  bunzipping: fma_small/000/000210.mp3
#  bunzipping: fma_small/000/000211.mp3
#  bunzipping: fma_small/000/000212.mp3
#  bunzipping: fma_small/000/000213.mp3
#  bunzipping: fma_small/000/000255.mp3
#  bunzipping: fma_small/000/000256.mp3
# ...

# %%
import librosa

# %%
'''
Spectrogram
'''
def stft(x,sr,title):
    X = librosa.stft(x)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(14, 8))
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.title(title)
    plt.ylim([0,400]) # y axis limit could be changed
    librosa.core.stft(x)
    return plt
    # plt.show()

'''
Mel-Spectrogram
'''
def MFCC(x,sr):
    mfccs = librosa.feature.mfcc(y=x, sr=sr, n_mfcc=20)
    delta_mfcc  = librosa.feature.delta(mfccs)
    delta2_mfcc = librosa.feature.delta(mfccs, order=2)
    mfcc_feature = np.concatenate((mfccs,delta_mfcc,delta2_mfcc))
    print(mfcc_feature)
    return mfcc_feature

# %%
base_path = "/fma_small/"
for i in range(100):
  if i < 10:
    string = "00"+str(i)
  else:
    string = "0"+str(i)
path = base_path+str()
